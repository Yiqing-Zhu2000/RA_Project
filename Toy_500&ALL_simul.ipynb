# %% [markdown]
# ### Aug_02
# select 1000 SNPs based on their (ordered) physical location (HG19) within chromosomes from dosage chr22 file.
# - first order by their location
# - pick first 1000 for which we assume its a block

# %%
import numpy as np
import pandas as pd
import magenpy as mgp
import viprs as vp
from viprs.eval.metrics import r2 
from data.utils.Simulate_training import *
from scipy.stats import pearsonr
import scipy.stats as chi2
from sklearn.decomposition import PCA
mgp.print_options()
# Out:
# -> Section: USER
# ---> plink2_path: /home/mcb/users/yzhu439/local/bin/plink2_file/plink2
# ---> plink1.9_path: /home/mcb/users/yzhu439/local/bin/plink_linux_x86_64/plink
# -> Section: DEFAULT
# ---> plink1.9_path: plink
# ---> plink2_path: plink2

# %%
# dosage chr22
chr22_dos = pd.read_csv("data/DREAM_RA_Responders_DosageData/Training_chr22.dos", 
                        sep=" ", header=None)
# genProb
chr22_gen = pd.read_csv("data/DREAM_RA_Responders_GenProbData/Training_chr22.gen", 
                        sep=" ", header=None)

# %%
# select 1000 SNPs with smallest locations
chr22_dos = pd.read_csv("data/DREAM_RA_Responders_DosageData/Training_chr22.dos", sep=" ", header=None)
chr22_dos.sort_values(by = chr22_dos.columns[2], inplace=True)
chr22_dos[chr22_dos.columns[1]][:1000].to_csv("CMAll_qced/selected1000_chr22.txt", 
                                             sep="\t", index=False, header=None)

# %% [markdown]
# <h3> Try to extract 1000 SNPs from genotype data</h3>
# 1. cd "~/RA_Project/CMAll_qced/chr22"
# 2. run:
# <code> plink --bfile ALL_CM_chr22 --extract ../selected1000_chr22.txt --make-bed --out Selected_1000snps </code>
# 3. Although we selected 1000 SNPs with smallest locations form the **dosage_chr22** file, but only <code>506 snps</code> pass the filter (existing the ALLchr22 training data)
#
# Based on those selected 506 snps, perform the simulation experiment on them.

# %%
from data.utils.Simulate_training import train_506_chr22

list_r2 = []
for i in range(1, 11):
    r_squ, elbo_list,pre, phe = train_506_chr22()
    list_r2.append(r_squ)
    plot_obs_vs_pred(phe, pre)
    pict_name = "ELBO_history_fig/chr22_selected506snps/506chr22_itr"+ str(i) + ".png"
    ELBO_plot(elbo_list, pict_name,itr=i)
    print("the r_suqare (r2)for the model trained above:", r_squ)
# Out:
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  11%|█         | 112/1000 [00:00<00:02, 359.84it/s]
# Exception ignored in: <finalize object at 0x7f34126fce30; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_y5ff2zht'
# Converged at iteration 113 || ELBO: -2218.384315
# > Final ELBO: -2218.384315
# > Estimated heritability: 0.542974
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# the r_suqare (r2)for the model trained above: 0.04317219003556294
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   3%|▎         | 30/1000 [00:00<00:02, 364.72it/s]
# Converged at iteration 31 || ELBO: -3834.666992
# > Final ELBO: -3834.666992
# > Estimated heritability: 0.003807
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f3400323af0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_iiiod66c'
# the r_suqare (r2)for the model trained above: 0.021698805571484885
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   5%|▌         | 52/1000 [00:00<00:02, 368.80it/s]
# Converged at iteration 53 || ELBO: -3494.765766
# > Final ELBO: -3494.765766
# > Estimated heritability: 0.226845
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec7c3430; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_rz7nsczx'
# the r_suqare (r2)for the model trained above: 0.055059150982124376
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   3%|▎         | 32/1000 [00:00<00:02, 362.91it/s]
# Converged at iteration 33 || ELBO: -3512.410987
# > Final ELBO: -3512.410987
# > Estimated heritability: 0.211325
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec7c3fb0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_d8g3967n'
# the r_suqare (r2)for the model trained above: 0.09805071471348219
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  12%|█▏        | 118/1000 [00:00<00:02, 358.98it/s]
# Exception ignored in: <finalize object at 0x7f34126fc930; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_vj12x_5w'
# Converged at iteration 119 || ELBO: -3010.227662
# > Final ELBO: -3010.227662
# > Estimated heritability: 0.376357
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# the r_suqare (r2)for the model trained above: 0.015177928097134818
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   1%|          | 10/1000 [00:00<00:03, 314.59it/s]
# Converged at iteration 11 || ELBO: -3824.078967
# > Final ELBO: -3824.078967
# > Estimated heritability: 0.018662
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec559e30; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_tdrqhbio'
# the r_suqare (r2)for the model trained above: 0.005859616199587452
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   4%|▍         | 41/1000 [00:00<00:02, 366.62it/s]
# Converged at iteration 42 || ELBO: -2889.779399
# > Final ELBO: -2889.779399
# > Estimated heritability: 0.425428
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec590310; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_xeqh8wr5'
# the r_suqare (r2)for the model trained above: 0.20324721381523245
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   1%|          | 7/1000 [00:00<00:03, 322.40it/s]
# Converged at iteration 8 || ELBO: -3824.061957
# > Final ELBO: -3824.061957
# > Estimated heritability: 0.018953
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec599bf0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_dudjeo00'
# the r_suqare (r2)for the model trained above: 0.01627442595353835
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   4%|▎         | 36/1000 [00:00<00:02, 371.86it/s]
# Converged at iteration 37 || ELBO: -3569.698198
# > Final ELBO: -3569.698198
# > Estimated heritability: 0.184488
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f33ec708530; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_r__os01_'
# the r_suqare (r2)for the model trained above: 0.06327619031682905
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   8%|▊         | 76/1000 [00:00<00:02, 353.72it/s]
# Exception ignored in: <finalize object at 0x7f33ec708360; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_52zlv420'
# Converged at iteration 77 || ELBO: -3430.125021
# > Final ELBO: -3430.125021
# > Estimated heritability: 0.237948
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# the r_suqare (r2)for the model trained above: 0.0032523330249101985

# %%
list_r2
# Out:
# [0.0027416332161233127,
#  0.06420734142605722,
#  0.12829216914974573,
#  0.03438395109231759,
#  0.011036985496435385,
#  0.12563577425770783,
#  0.0029407868221914173,
#  0.09654715232582912,
#  0.012495335820686135,
#  0.16408107522921034]

# %% [markdown]
# <h3>Simulate for ALL chr22 genotypes in 2706 patients. </h3>
# This will take a long time to run.Repeat training on ALL-chr22 10 times.
# The traininig funciton is in "data/utils/training.py", calculate r^2 on itself.

# %%
from data.utils.Simulate_training import *

chr22ALL_r2s = []
for i in range(1,11):
    R2, ELBO_list, phe, pre = train_chr22ALL()
    print("The ", i, " th simulation experiment, ", "the r^2 is ", R2)
    elbo_path = "ELBO_history_fig/chr22_ALLsnps/chr22ALL_itr" + str(i) + ".png"
    ELBO_plot(ELBO_list, elbo_path, i)
    plot_obs_vs_pred(phe, pre)
    chr22ALL_r2s.append(R2)
# Out:
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
# 100%|██████████| 1000/1000 [09:28<00:00,  1.76it/s]
# /home/mcb/users/yzhu439/RA_Project/data/utils/Simulate_training.py:188: UserWarning: Maximum iterations reached without convergence. You may need to run the model for more iterations.
#   v.fit()
# > Final ELBO: 17064.126807
# > Estimated heritability: 0.828298
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b63015e30; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_571lfve8'
# The  1  th simulation experiment,  the r^2 is  0.03181572892431399
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#   8%|▊         | 85/1000 [00:49<08:49,  1.73it/s]
# Converged at iteration 86 || ELBO: -3607.180105
# > Final ELBO: -3607.180105
# > Estimated heritability: 0.209048
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b600b78b0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_yk5e82za'
# The  2  th simulation experiment,  the r^2 is  0.06713421620691305
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  14%|█▍        | 142/1000 [01:24<08:29,  1.68it/s]
# Converged at iteration 143 || ELBO: -2051.946602
# > Final ELBO: -2051.946602
# > Estimated heritability: 0.588640
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b600b7aa0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_3pvasows'
# The  3  th simulation experiment,  the r^2 is  0.08571637608243426
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  56%|█████▌    | 556/1000 [05:22<04:17,  1.72it/s]
# Converged at iteration 557 || ELBO: 7544.356568
# > Final ELBO: 7544.356568
# > Estimated heritability: 0.822385
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b6003a5e0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_lir7vd80'
# The  4  th simulation experiment,  the r^2 is  0.06360953120201482
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  65%|██████▍   | 648/1000 [06:02<03:17,  1.79it/s]
# Converged at iteration 649 || ELBO: -772.870068
# > Final ELBO: -772.870068
# > Estimated heritability: 0.692683
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b63015f20; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_trx80844'
# The  5  th simulation experiment,  the r^2 is  0.01689500870151904
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
# 100%|██████████| 1000/1000 [09:31<00:00,  1.75it/s]
# /home/mcb/users/yzhu439/RA_Project/data/utils/Simulate_training.py:188: UserWarning: Maximum iterations reached without convergence. You may need to run the model for more iterations.
#   v.fit()
# > Final ELBO: 87143.071294
# > Estimated heritability: 0.941302
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b282e3610; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_5il43rjm'
# The  6  th simulation experiment,  the r^2 is  6.570936877729968e-06
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  24%|██▎       | 237/1000 [02:16<07:20,  1.73it/s]
# Converged at iteration 238 || ELBO: -3018.717276
# > Final ELBO: -3018.717276
# > Estimated heritability: 0.403796
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b6003a750; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_6imfbx4a'
# The  7  th simulation experiment,  the r^2 is  0.07153426382110617
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  30%|███       | 303/1000 [02:51<06:35,  1.76it/s]/home/mcb/users/yzhu439/RA_Project/data/utils/Simulate_training.py:188: UserWarning: Iteration 304: ELBO dropped from -1935.104761 to -1935.116820.
#   v.fit()
#  30%|███       | 304/1000 [02:52<06:34,  1.76it/s]/home/mcb/users/yzhu439/RA_Project/data/utils/Simulate_training.py:188: UserWarning: Iteration 305: ELBO dropped from -1935.116820 to -1935.128798.
#   v.fit()
#  51%|█████     | 507/1000 [04:49<04:41,  1.75it/s]
# Converged at iteration 508 || ELBO: -1927.106107
# > Final ELBO: -1927.106107
# > Estimated heritability: 0.592415
# > Estimated proportion of causal variants: 0.001000
# > Generating polygenic scores...
# Exception ignored in: <finalize object at 0x7f8b6003a0d0; dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/weakref.py", line 572, in __call__
#     return info.func(*info.args, **(info.kwargs or {}))
#   File "/usr/lib/python3.7/tempfile.py", line 934, in _cleanup
#     _rmtree(name)
#   File "/usr/lib/python3.7/shutil.py", line 485, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.7/shutil.py", line 483, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: 'temp/ld_8mamoflh'
# The  8  th simulation experiment,  the r^2 is  0.05358246190333602
# > Reading BED file...
# > Generating polygenic scores...
# > Performing GWAS...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Reading BED file...
# > Reading summary statistics file...
# > Harmonizing data...
# > Computing LD matrix...
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/array/routines.py:318: PerformanceWarning: Increasing number of chunks by factor of 18
#   axes=(left_axes, right_axes),
# /home/mcb/users/yzhu439/RA_Project/.venv/lib/python3.7/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# > Initializing model parameters
# > Loading LD matrices into memory...
# > Performing model fit...
# > Using up to 1 threads.
#  15%|█▌        | 152/1000 [01:29<08:19,  1.70it/s]
# ---------------------------------------------------------------------------
# OptimizationDivergence                    Traceback (most recent call last)
# /tmp/ipykernel_12541/1751443848.py in <module>
#       3 chr22ALL_r2s = []
#       4 for i in range(1,11):
# ----> 5     R2, ELBO_list, phe, pre = train_chr22ALL()
#       6     print("The ", i, " th simulation experiment, ", "the r^2 is ", R2)
#       7     elbo_path = "ELBO_history_fig/chr22_ALLsnps/chr22ALL_itr" + str(i) + ".png"
#
# ~/RA_Project/data/utils/Simulate_training.py in train_chr22ALL()
#     186     # viprs
#     187     v = vp.VIPRS(gdl_sim, fix_params={'pi': 0.001, 'sigma_epsilon': 0.999})
# --> 188     v.fit()
#     189
#     190     # predict on the same dataset directly
#
# viprs/model/VIPRS.pyx in viprs.model.VIPRS.VIPRS.fit()
#
# viprs/model/VIPRS.pyx in viprs.model.VIPRS.VIPRS.fit()
#
# OptimizationDivergence: Stopping at iteration 153: The optimization algorithm is not converging!
# Previous ELBO: -1017.050216 | Current ELBO: 240.514797

# %%
chr22ALL_r2s
# Out:
# [0.03181572892431399,
#  0.06713421620691305,
#  0.08571637608243426,
#  0.06360953120201482,
#  0.01689500870151904,
#  6.570936877729968e-06,
#  0.07153426382110617,
#  0.05358246190333602]
